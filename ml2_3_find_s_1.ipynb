# %% [markdown]
# <a href="https://colab.research.google.com/github/Amogh-S-Acharya/ML2-AMOGH_S_ACHARYA-4NI23CI012/blob/main/ml2_3_find_s_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = [
    ["Sunny", "Hot", "High", "Weak", "No"],
    ["Sunny", "Hot", "High", "Strong", "No"],
    ["Overcast", "Hot", "High", "Weak", "Yes"],
    ["Rainy", "Mild", "High", "Weak", "Yes"],
    ["Rainy", "Cool", "Normal", "Weak", "Yes"],
    ["Rainy", "Cool", "Normal", "Strong", "No"],
    ["Overcast", "Cool", "Normal", "Strong", "Yes"],
    ["Sunny", "Mild", "High", "Weak", "No"],
    ["Sunny", "Cool", "Normal", "Weak", "Yes"],
    ["Rainy", "Mild", "Normal", "Weak", "Yes"]
]

columns = ["Outlook", "Temperature", "Humidity", "Wind", "PlayTennis"]

df = pd.DataFrame(data, columns=columns)

x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

hypothesis = None
for i in range(len(x)):
  if y[i] == 'Yes':
    if hypothesis is None:
      hypothesis = x[i].copy()
    else:
      for j in range(len(hypothesis)):
        if hypothesis[j] != x[i][j]:
          hypothesis[j] = '?'
  print("step", i+1,  "hypothesis" , hypothesis)
print("\n Final Hypothesis: " , hypothesis)
# Out:
# step 1 hypothesis None
# step 2 hypothesis None
# step 3 hypothesis ['Overcast' 'Hot' 'High' 'Weak']
# step 4 hypothesis ['?' '?' 'High' 'Weak']
# step 5 hypothesis ['?' '?' '?' 'Weak']
# step 6 hypothesis ['?' '?' '?' 'Weak']
# step 7 hypothesis ['?' '?' '?' '?']
# step 8 hypothesis ['?' '?' '?' '?']
# step 9 hypothesis ['?' '?' '?' '?']
# step 10 hypothesis ['?' '?' '?' '?']
#
#  Final Hypothesis:  ['?' '?' '?' '?']
