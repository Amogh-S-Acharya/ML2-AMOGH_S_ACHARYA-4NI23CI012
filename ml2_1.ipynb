# %% [markdown]
# <a href="https://colab.research.google.com/github/Amogh-S-Acharya/ML2-AMOGH_S_ACHARYA-4NI23CI012/blob/main/ml2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/content/stud_data.csv')

# %%
df
# Out:
#     student_id   age  gender  study_hours  attendance  marks result
# 0            1  18.0    Male          2.0          75     58   Pass
# 1            2  19.0  Female          0.0          88     76   Pass
# 2            3  18.0    Male          1.0          65     42   Fail
# 3            4  20.0  Female          5.0          92     85   Pass
# 4            5  19.0    Male          3.0          80     67   Pass
# 5            6  18.0  Female          2.0          70     51   Pass
# 6            7  21.0    Male          NaN          60     38   Fail
# 7            8  20.0  Female          6.0          95     91   Pass
# 8            9  19.0    Male          4.0          85     73   Pass
# 9           10  18.0  Female          2.0          68     45   Fail
# 10          11  21.0    Male          5.0          90     82   Pass
# 11          12   NaN  Female          3.0          78     64   Pass
# 12          13  19.0    Male          1.0          55     35   Fail
# ...

# %%
df.head()
# Out:
#    student_id   age  gender  study_hours  attendance  marks result
# 0           1  18.0    Male          2.0          75     58   Pass
# 1           2  19.0  Female          0.0          88     76   Pass
# 2           3  18.0    Male          1.0          65     42   Fail
# 3           4  20.0  Female          5.0          92     85   Pass
# 4           5  19.0    Male          3.0          80     67   Pass

# %%
df.tail()
# Out:
#     student_id   age  gender  study_hours  attendance  marks result
# 10          11  21.0    Male          5.0          90     82   Pass
# 11          12   NaN  Female          3.0          78     64   Pass
# 12          13  19.0    Male          1.0          55     35   Fail
# 13          14  18.0  Female          4.0          87     79   Pass
# 14          15  20.0    Male          3.0          82     69    NaN

# %%
df.shape
# Out:
# (15, 7)

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours', 'attendance', 'marks',
#        'result'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# student_id     0
# age            1
# gender         0
# study_hours    1
# attendance     0
# marks          0
# result         1
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#     student_id   age  gender  study_hours  attendance  marks result
# 0            1  18.0    Male          2.0          75     58   Pass
# 1            2  19.0  Female          0.0          88     76   Pass
# 2            3  18.0    Male          1.0          65     42   Fail
# 3            4  20.0  Female          5.0          92     85   Pass
# 4            5  19.0    Male          3.0          80     67   Pass
# 5            6  18.0  Female          2.0          70     51   Pass
# 7            8  20.0  Female          6.0          95     91   Pass
# 8            9  19.0    Male          4.0          85     73   Pass
# 9           10  18.0  Female          2.0          68     45   Fail
# 10          11  21.0    Male          5.0          90     82   Pass
# 12          13  19.0    Male          1.0          55     35   Fail
# 13          14  18.0  Female          4.0          87     79   Pass

# %%
df['study_hours'] = df['study_hours'].fillna(df['study_hours'].median())
df['result'] = df['result'].fillna(df['result'].mode()[0])

# %%
df
# Out:
#     student_id   age  gender  study_hours  attendance  marks result
# 0            1  18.0    Male          2.0          75     58   Pass
# 1            2  19.0  Female          0.0          88     76   Pass
# 2            3  18.0    Male          1.0          65     42   Fail
# 3            4  20.0  Female          5.0          92     85   Pass
# 4            5  19.0    Male          3.0          80     67   Pass
# 5            6  18.0  Female          2.0          70     51   Pass
# 6            7  21.0    Male          3.0          60     38   Fail
# 7            8  20.0  Female          6.0          95     91   Pass
# 8            9  19.0    Male          4.0          85     73   Pass
# 9           10  18.0  Female          2.0          68     45   Fail
# 10          11  21.0    Male          5.0          90     82   Pass
# 11          12   NaN  Female          3.0          78     64   Pass
# 12          13  19.0    Male          1.0          55     35   Fail
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#     student_id   age  gender  study_hours  attendance  marks result
# 0            1  18.0    Male          2.0          75     58   Pass
# 1            2  19.0  Female          0.0          88     76   Pass
# 2            3  18.0    Male          1.0          65     42   Fail
# 3            4  20.0  Female          5.0          92     85   Pass
# 4            5  19.0    Male          3.0          80     67   Pass
# 5            6  18.0  Female          2.0          70     51   Pass
# 6            7  21.0    Male          NaN          60     38   Fail
# 7            8  20.0  Female          6.0          95     91   Pass
# 8            9  19.0    Male          4.0          85     73   Pass
# 9           10  18.0  Female          2.0          68     45   Fail
# 10          11  21.0    Male          5.0          90     82   Pass
# 11          12   NaN  Female          3.0          78     64   Pass
# 12          13  19.0    Male          1.0          55     35   Fail
# ...

# %%
df.describe()
# Out:
#        student_id        age  study_hours  attendance      marks
# count   15.000000  14.000000    14.000000   15.000000  15.000000
# mean     8.000000  19.142857     2.928571   78.000000  63.666667
# std      4.472136   1.099450     1.730464   12.171395  18.014544
# min      1.000000  18.000000     0.000000   55.000000  35.000000
# 25%      4.500000  18.000000     2.000000   69.000000  48.000000
# 50%      8.000000  19.000000     3.000000   80.000000  67.000000
# 75%     11.500000  20.000000     4.000000   87.500000  77.500000
# max     15.000000  21.000000     6.000000   95.000000  91.000000

# %%
# Describe the 'gender' column
print("Description of 'gender' column:")
display(df['gender'].value_counts())

# %%
# Describe the 'result' column
print("\nDescription of 'result' column:")
display(df['result'].value_counts())

# %%
# Using .describe() on the 'gender' column
print("Descriptive statistics for 'gender' column using .describe():")
display(df['gender'].describe())

# %%
# Using .describe() on the 'result' column
print("\nDescriptive statistics for 'result' column using .describe():")
display(df['result'].describe())
# Out:
# Descriptive statistics for 'result' column using .describe():
# count       15
# unique       2
# top       Pass
# freq        11
# Name: result, dtype: object

# %%
plt.hist(df['marks'], bins = 10, edgecolor = 'k')
plt.xlabel('marks')
plt.ylabel('Frequency')
plt.title('Distribution of marks')
plt.show()

# %%
c= df.corr(numeric_only=True)
print(c)
# Out:
#              student_id       age  study_hours  attendance     marks
# student_id     1.000000  0.211163     0.288585   -0.015747  0.039011
# age            0.211163  1.000000     0.601519    0.265882  0.309565
# study_hours    0.288585  0.601519     1.000000    0.706913  0.746427
# attendance    -0.015747  0.265882     0.706913    1.000000  0.992289
# marks          0.039011  0.309565     0.746427    0.992289  1.000000
